# %%
# %run hockey.py

# %%
freda = League()
freda.add_team(Team("Evan Gomolin", load=True))
freda.add_team(Team("Daniel Sandler", load=True))
freda.add_team(Team("Adam Deverett", load=True))
freda.add_team(Team("Benji Stern", load=True))
freda.add_team(Team("Josh Waksman", load=True))
freda.add_team(Team("David Waksman", load=True))
freda.add_team(Team("Noah Waksman", load=True))
freda.add_team(Team("Noah Nightingale", load=True))
freda.add_team(Team("Moshe Elmaleh", load=True))
freda.add_team(Team("Eli Sherman", load=True))
freda.add_team(Team("Josh Silverman", load=True))
freda.add_team(Team("Adam Fishman", load=True))

freda.show_league()
# Out:
# Roster for Evan Gomolin
#
# Players:
#
# Keepers:
# Jack Hughes costs $4 and is signed to a 3 year contract
# Cale Makar costs $4 and is signed to a 3 year contract
# Timo Meier costs $9 and is signed to a 2 year contract
# Darcy Kuemper costs $15 and is signed to a 1 year contract
# Kasperi Kapanen costs $4 and is signed to a 1 year contract
#
# Prospects:
# Alex Newhook is a prospect
# Arthur Kaliyev is a prospect
# Eeli Tolvanen is a prospect
# Joe Veleno is a prospect
# Trevor Zegras is a prospect
# Ryan Suzuki is a prospect
# Ukko-Pekka Luukkonen is a prospect
#
# Roster for Daniel Sandler
#
# Players:
#
# Keepers:
# Elvis Merzlikins costs $4 and is signed to a 2 year contract
# Tomas Hertl costs $11 and is signed to a 2 year contract
# Kevin Fiala costs $6 and is signed to a 2 year contract
# Max Domi costs $9 and is signed to a 1 year contract
# John Carlson costs $41 and is signed to a 1 year contract
# Neal Pionk costs $4 and is signed to a 1 year contract
#
# Prospects:
# ...
